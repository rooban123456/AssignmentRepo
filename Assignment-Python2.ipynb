# %%
for i in range(5):
    print('*'*i)
else:
    for i in range(-4,1):
        print('*'*(1-i))
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
a=input("Enter a word:")
b=a[::-1]
print(b)
# Out:
# Enter a word:Rooban
# nabooR
